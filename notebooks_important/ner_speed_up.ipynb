# %%
import re
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
import nltk

from tqdm import tqdm
from string import punctuation
from sklearn.metrics import f1_score

from dostoevsky.tokenization import RegexTokenizer
from flashtext import KeywordProcessor

# %% [markdown]
# Попытка ускорить спейси с 30 минут с помощью конфигурирования пайплайна:

# %%
sns.set_theme()
tqdm.pandas()

nlp = spacy.load(
    'ru_core_news_sm',
    enable=['ner', 'tokenizer'],
    exclude=['tok2vec', 'attribute_ruler', 'morphologizer', 'senter', 'lemmatizer']
)
nlp.config
# Out:
# c:\Users\sveta\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'ru_core_news_sm' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# {'paths': {'train': None, 'dev': None, 'vectors': None, 'init_tok2vec': None},
#  'system': {'gpu_allocator': None, 'seed': 0},
#  'nlp': {'lang': 'ru',
#   'pipeline': ['parser', 'ner'],
#   'disabled': ['parser'],
#   'before_creation': None,
#   'after_creation': None,
#   'after_pipeline_creation': None,
#   'batch_size': 256,
#   'tokenizer': {'@tokenizers': 'spacy.Tokenizer.v1'}},
#  'components': {'parser': {'factory': 'parser',
#    'learn_tokens': False,
#    'min_action_freq': 30,
#    'model': {'@architectures': 'spacy.TransitionBasedParser.v2',
#     'state_type': 'parser',
#     'extra_state_tokens': False,
#     'hidden_width': 64,
#     'maxout_pieces': 2,
#     'use_upper': True,
#     'nO': None,
#     'tok2vec': {'@architectures': 'spacy.Tok2VecListener.v1',
#      'width': '${components.tok2vec.model.encode:width}',
#      'upstream': 'tok2vec'}},
#    'moves': None,
#    'scorer': {'@scorers': 'spacy.parser_scorer.v1'},
#    'update_with_oracle_cut_size': 100},
#   'ner': {'factory': 'ner',
#    'incorrect_spans_key': None,
#    'model': {'@architectures': 'spacy.TransitionBasedParser.v2',
#     'state_type': 'ner',
#     'extra_state_tokens': False,
#     'hidden_width': 64,
#     'maxout_pieces': 2,
#     'use_upper': True,
#     'nO': None,
#     'tok2vec': {'@architectures': 'spacy.Tok2Vec.v2',
#      'embed': {'@architectures': 'spacy.MultiHashEmbed.v2',
#       'width': 96,
#       'attrs': ['NORM', 'PREFIX', 'SUFFIX', 'SHAPE'],
#       'rows': [5000, 1000, 2500, 2500],
#       'include_static_vectors': False},
#      'encode': {'@architectures': 'spacy.MaxoutWindowEncoder.v2',
#       'width': 96,
#       'depth': 4,
#       'window_size': 1,
#       'maxout_pieces': 3}}},
#    'moves': None,
#    'scorer': {'@scorers': 'spacy.ner_scorer.v1'},
#    'update_with_oracle_cut_size': 100}},
#  'corpora': {'dev': {'@readers': 'spacy.Corpus.v1',
#    'path': '${paths.dev}',
#    'gold_preproc': False,
#    'max_length': 0,
#    'limit': 0,
#    'augmenter': None},
#   'train': {'@readers': 'spacy.Corpus.v1',
#    'path': '${paths.train}',
#    'gold_preproc': False,
#    'max_length': 0,
#    'limit': 0,
#    'augmenter': None}},
#  'training': {'train_corpus': 'corpora.train',
#   'dev_corpus': 'corpora.dev',
#   'seed': '${system:seed}',
#   'gpu_allocator': '${system:gpu_allocator}',
#   'dropout': 0.1,
#   'accumulate_gradient': 1,
#   'patience': 5000,
#   'max_epochs': 0,
#   'max_steps': 100000,
#   'eval_frequency': 1000,
#   'frozen_components': [],
#   'before_to_disk': None,
#   'annotating_components': [],
#   'before_update': None,
#   'batcher': {'@batchers': 'spacy.batch_by_words.v1',
#    'discard_oversize': False,
#    'tolerance': 0.2,
#    'get_length': None,
#    'size': {'@schedules': 'compounding.v1',
#     'start': 100,
#     'stop': 1000,
#     'compound': 1.001,
#     't': 0.0}},
#   'logger': {'@loggers': 'spacy.ConsoleLogger.v1', 'progress_bar': False},
#   'optimizer': {'@optimizers': 'Adam.v1',
#    'beta1': 0.9,
#    'beta2': 0.999,
#    'L2_is_weight_decay': True,
#    'L2': 0.01,
#    'grad_clip': 1.0,
#    'use_averages': True,
#    'eps': 1e-08,
#    'learn_rate': 0.001},
#   'score_weights': {'dep_uas': 0.0,
#    'dep_las': 0.16,
#    'dep_las_per_type': None,
#    'sents_p': None,
#    'sents_r': None,
#    'sents_f': 0.02,
#    'ents_f': 0.16,
#    'ents_p': 0.0,
#    'ents_r': 0.0,
#    'ents_per_type': None,
#    'pos_acc': 0.08,
#    'morph_acc': 0.08,
#    'morph_per_feat': None,
#    'lemma_acc': 0.5,
#    'speed': 0.0}},
#  'pretraining': {},
#  'initialize': {'vocab_data': None,
#   'vectors': '${paths.vectors}',
#   'init_tok2vec': '${paths.init_tok2vec}',
#   'before_init': None,
#   'after_init': None,
#   'components': {'morphologizer': {'labels': {'@readers': 'spacy.read_labels.v1',
#      'path': 'corpus/labels/morphologizer.json',
#      'require': False}},
#    'ner': {'labels': {'@readers': 'spacy.read_labels.v1',
#      'path': 'corpus/labels/ner.json',
#      'require': False}},
#    'parser': {'labels': {'@readers': 'spacy.read_labels.v1',
#      'path': 'corpus/labels/parser.json',
#      'require': False}}},
#   'lookups': {'@misc': 'spacy.LookupsDataLoader.v1',
#    'lang': '${nlp.lang}',
#    'tables': []},
#   'tokenizer': {}}}

# %%
DATA_PATH = 'data'
RANDOM_STATE = 42
COMPANY_REGEX = r'".+"'

# %%
df = pd.read_pickle(DATA_PATH + '/mentions texts.pickle')
df.head()
# Out:
#     ChannelID  messageid  issuerid  MessageID           DateAdded  \
# 0  1197210433       5408        90       5408 2021-02-06 01:42:42
# 1  1203560567      64803        57      64803 2021-02-06 01:47:00
# 2  1197210433      23389       152      23389 2021-07-21 13:46:31
# 3  1066174394        677       112        677 2021-09-21 04:23:59
# 4  1239405989       4486       115       4486 2023-01-20 15:02:22
#
#            DatePosted                                        MessageText  \
# 0 2020-04-29 07:29:01  ?? Фокус недели #ФН  Сегодня ????? ММК опублик...
# 1 2020-01-21 12:51:42  ??#LSRG  ЛСР - операционные результаты (2019г)...
# 2 2021-07-21 11:15:46  #CHMF Северсталь (CHMF) впервые поставила в Бр...
# 3 2016-12-16 10:00:04  "Версия: Многоходовочка по Роснефти  Роснефтег...
# 4 2023-01-20 13:03:38  🟢 Новости к этому часу   ⚪️ФРС США необходимо ...
#
#    IsForward
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# Семплируем тестовые данные с запасом

# %%
samples = df.sample(1100, random_state=RANDOM_STATE)
samples.head()
# Out:
#         ChannelID  messageid  issuerid  MessageID           DateAdded  \
# 3725   1203560567      52298       187      52298 2021-02-06 01:47:00
# 13914  1565800335       1955       150       1955 2023-11-12 07:46:15
# 9347   1203560567      55570       175      55570 2021-02-06 01:47:00
# 7527   1203560567     227127         7     227127 2023-01-30 15:01:09
# 4336   1351339368        736         7        736 2021-02-06 19:06:57
#
#                DatePosted                                        MessageText  \
# 3725  2019-09-24 16:47:30  ????????#крипто #франция #внедрение К началу 2...
# 13914 2023-11-12 07:30:00  ​🏦 Сбербанк (SBER) - чистая продолжает бить ре...
# 9347  2019-10-22 11:31:05  ??#TRNFP #бонды ТРАНСНЕФТЬ ПЕРЕНЕСЛА СБОР ЗАЯВ...
# 7527  2023-01-30 11:32:10  "🇷🇺#RTKM #VTBR #цифровизация #россия  ""Ростел...
# 4336  2020-03-30 09:56:53  Доброе утро!   ?? В пятницу Федрезерв США объя...
#
#        IsForward
# 3725       False
# 13914      False
# 9347       False
# 7527       False
# 4336       False

# %% [markdown]
# После оптимизации пайплайна спейси обрабатывает 1100 текстов за ~25-30 секунд

# %%
samples['spacy'] = samples['MessageText'].progress_apply(nlp)
# Out:
# 100%|██████████| 1100/1100 [00:24<00:00, 45.25it/s]

# %%
samples['sentences'] = samples['MessageText'].progress_apply(nltk.sent_tokenize)
# Out:
# 100%|██████████| 1100/1100 [00:00<00:00, 1573.47it/s]

# %% [markdown]
# Попробуем оптимизировать нер, воспользовавшись префиксным деревом. Для этого подготовим данные:

# %%
synonyms_mapper = pd.read_excel(DATA_PATH + f'/names and synonyms.xlsx', index_col='issuerid')
synonyms_mapper
# Out:
#                                           EMITENT_FULL_NAME  VeryOddCompany  \
# issuerid
# 1         Акционерный коммерческий банк "Держава" публич...             NaN
# 2         "МОСКОВСКИЙ КРЕДИТНЫЙ БАНК" (публичное акционе...             NaN
# 3         "Российский акционерный коммерческий дорожный ...             NaN
# 4         Акционерная компания "АЛРОСА" (публичное акцио...             NaN
# 5         Акционерный Коммерческий банк "АВАНГАРД" - пуб...             NaN
# ...                                                     ...             ...
# 270                                               Henderson             NaN
# 271                                              Совкомбанк             NaN
# 272                                               ЕвроТранс             NaN
# 273                                              Делимобиль             NaN
# 274                                                 Диасофт             NaN
#
#          BGTicker BGTicker.1  \
# issuerid
# 1             NaN      DERZP
# 2         CBOM RX        NaN
# 3             NaN       RDRB
# 4         ALRS RX        NaN
# 5             NaN       AVAN
# ...           ...        ...
# 270           NaN       HNFG
# 271           NaN       SVCB
# 272           NaN       EUTR
# 273           NaN       DELI
# 274           NaN       DIAS
#
#                                                  Unnamed: 5     Unnamed: 6  \
# issuerid
# 1                                                   Держава       DERZHAVA
# 2                                 Московский кредитный банк            мкб
# 3         Российский акционерный коммерческий дорожный банк         РДБанк
# 4                                                    алроса         alrosa
# 5                                                  Авангард       AVANGARD
# ...                                                     ...            ...
# 270                                               Хендерсон            NaN
# 271                                              Sovcombank            NaN
# 272                                              АЗС Трасса   АЗС "Трасса"
# 273                                               Делимобил  Каршеринг Рус
# 274                                                 Diasoft            NaN
#
#                      Unnamed: 7  \
# issuerid
# 1                          DERZ
# 2         Credit Bank of Moscow
# 3                 Дорожный банк
# 4                           NaN
# 5                           NaN
# ...                         ...
# 270                         NaN
# 271                         NaN
# 272                АЗС «Трасса»
# 273                   delimobil
# 274                         NaN
#
#                                                 Unnamed: 8  \
# issuerid
# 1                                                      NaN
# 2                                              Credit Bank
# 3         Russian public joint-stock commercial roads Bank
# 4                                                      NaN
# 5                                                      NaN
# ...                                                    ...
# 270                                                    NaN
# 271                                                    NaN
# 272                                                    NaN
# 273                                 ПАО "Каршеринг Руссия"
# 274                                                    NaN
#
#                        Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# issuerid
# 1                             NaN         NaN         NaN         NaN
# 2                             NaN         NaN         NaN         NaN
# 3                      RosDorBank  РосДорБанк  roads Bank         NaN
# 4                             NaN         NaN         NaN         NaN
# 5                             NaN         NaN         NaN         NaN
# ...                           ...         ...         ...         ...
# 270                           NaN         NaN         NaN         NaN
# 271                           NaN         NaN         NaN         NaN
# 272                           NaN         NaN         NaN         NaN
# 273       "Каршеринг Руссия", ПАО         NaN         NaN         NaN
# 274                           NaN         NaN         NaN         NaN
#
#          Unnamed: 13 Unnamed: 14
# issuerid
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# 5                NaN         NaN
# ...              ...         ...
# 270              NaN         NaN
# 271              NaN         NaN
# 272              NaN         NaN
# 273              NaN         NaN
# 274              NaN         NaN
#
# [255 rows x 14 columns]

# %%
synonyms_mapper['extended'] = synonyms_mapper['BGTicker'].apply(lambda x: x.split()[0] if not pd.isna(x) else x)

synonyms_mapper['extended_2'] = synonyms_mapper['EMITENT_FULL_NAME'].apply(
    lambda x: re.findall(COMPANY_REGEX, x)[0] if re.findall(COMPANY_REGEX, x) else None
)

# %%
synonyms_cols = ['EMITENT_FULL_NAME', 'VeryOddCompany', 'BGTicker', 'BGTicker.1',
       'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'extended', 'extended_2']

synonyms_list = synonyms_mapper[synonyms_cols].values
synonyms_list
# Out:
# array([['Акционерный коммерческий банк "Держава" публичное акционерное общество',
#         nan, nan, ..., nan, nan, '"Держава"'],
#        ['"МОСКОВСКИЙ КРЕДИТНЫЙ БАНК" (публичное акционерное общество)',
#         nan, 'CBOM RX', ..., nan, 'CBOM', '"МОСКОВСКИЙ КРЕДИТНЫЙ БАНК"'],
#        ['"Российский акционерный коммерческий дорожный банк" (публичное акционерное общество)',
#         nan, nan, ..., nan, nan,
#         '"Российский акционерный коммерческий дорожный банк"'],
#        ...,
#        ['ЕвроТранс', nan, nan, ..., nan, nan, None],
#        ['Делимобиль', nan, nan, ..., nan, nan, None],
#        ['Диасофт', nan, nan, ..., nan, nan, None]], dtype=object)

# %%
synonyms_list = [[f'{synonym.strip()}' for synonym in synonyms_list if not pd.isna(synonym)] for synonyms_list in synonyms_list]
keyword_dict = dict(zip(synonyms_mapper.index.values, synonyms_list))

keyword_dict
# Out:
# {1: ['Акционерный коммерческий банк "Держава" публичное акционерное общество',
#   'DERZP',
#   'Держава',
#   'DERZHAVA',
#   'DERZ',
#   '"Держава"'],
#  2: ['"МОСКОВСКИЙ КРЕДИТНЫЙ БАНК" (публичное акционерное общество)',
#   'CBOM RX',
#   'Московский кредитный банк',
#   'мкб',
#   'Credit Bank of Moscow',
#   'Credit Bank',
#   'CBOM',
#   '"МОСКОВСКИЙ КРЕДИТНЫЙ БАНК"'],
#  3: ['"Российский акционерный коммерческий дорожный банк" (публичное акционерное общество)',
#   'RDRB',
#   'Российский акционерный коммерческий дорожный банк',
#   'РДБанк',
#   'Дорожный банк',
#   'Russian public joint-stock commercial roads Bank',
#   'RosDorBank',
#   'РосДорБанк',
#   'roads Bank',
#   '"Российский акционерный коммерческий дорожный банк"'],
#  4: ['Акционерная компания "АЛРОСА" (публичное акционерное общество)',
#   'ALRS RX',
#   'алроса',
#   'alrosa',
#   'ALRS',
#   '"АЛРОСА"'],
#  5: ['Акционерный Коммерческий банк "АВАНГАРД" - публичное акционерное общество',
#   'AVAN',
#   'Авангард',
#   'AVANGARD',
#   '"АВАНГАРД"'],
#  6: ['акционерный коммерческий банк "Приморье"  (публичное акционерное общество)',
#   'PRMB',
#   'АКБ Приморье',
#   'АКБ "Приморье"',
#   'банк "Приморье"',
#   'банк Приморье',
#   'primbank',
#   'PJSCB "Primorye"',
#   'PJSCB Primorye',
#   'public joint-stock commercial bank "Primorye"',
#   'bank "Primorye"',
#   'bank Primorye',
#   '"Приморье"'],
#  7: ['Банк ВТБ (публичное акционерное общество)',
#   'VTBR RX',
#   'ВТБ',
#   'VTB',
#   'VTBR'],
#  8: ['Иркутское публичное акционерное общество энергетики и электрификации',
#   'IRGZ',
#   'Иркутскэнерго',
#   'ИркЭнерго',
#   'Irkutskenergo'],
#  9: ['Казанское публичное акционерное общество "Органический синтез"',
#   'KZOS',
#   'Органический синтез',
#   'Казаньоргсинтез',
#   'kazanorgsintez',
#   '"Органический синтез"'],
#  10: ['Ленское золотодобывающее публичное акционерное общество "Лензолото"',
#   'LNZL',
#   'Лензолото',
#   'Lenzoloto',
#   '"Лензолото"'],
#  11: ['Международная компания публичное акционерное общество "Объединённая Компания "РУСАЛ"',
#   'RUAL RX',
#   'RUAL',
#   'Объединённая компания "Русал"',
#   'русал',
#   'rusal',
#   'RUAL',
#   '"Объединённая Компания "РУСАЛ"'],
#  12: ['Международная компания публичное акционерное общество "ЭН+ ГРУП"',
#   'ENPG RX',
#   'ENPL',
#   'эн+ груп',
#   'En+ Group',
#   'EN+ Group Plc',
#   'ENPG',
#   '"ЭН+ ГРУП"'],
#  13: ['Открытое акционерное общество "Белон"',
#   'BLNG',
#   'Белон',
#   'belon',
#   '"Белон"'],
#  14: ['Открытое акционерное общество "Донской завод радиодеталей"',
#   'DZRD',
#   'Донской завод радиодеталей',
#   'ДЗРД',
#   '"Донской завод радиодеталей"'],
#  15: ['Открытое акционерное общество "Левенгук"',
#   'LVHK',
#   'Левенгук',
#   'levenhuk',
#   '"Левенгук"'],
#  16: ['Открытое акционерное общество "Липецкая энергосбытовая компания"',
#   'LPSB',
#   'LPSBG',
#   'Липецкая энергосбытовая компания',
#   'Липецкая ЭСК',
#   'ЛЭСК',
#   'lesk',
#   '"Липецкая энергосбытовая компания"'],
#  17: ['Открытое акционерное общество "Межрегиональная распределительная сетевая компания Урала"',
#   'MRKU',
#   'Межрегиональная распределительная сетевая компания Урала',
#   'МРСК Урала',
#   'Россети Урал',
#   'rosseti ural',
#   '"Межрегиональная распределительная сетевая компания Урала"'],
#  18: ['Открытое акционерное общество "Мультисистема"',
#   'MSST',
#   'Мультисистема',
#   'multisistema',
#   '"Мультисистема"'],
#  19: ['Открытое акционерное общество "Научно-производственное объединение "Физика"',
#   'NPOF',
#   'Научно-производственное объединение "Физика"',
#   'НПО "Физика"',
#   'НПО Физика',
#   'npofizika',
#   '"Научно-производственное объединение "Физика"'],
#  20: ['Открытое акционерное общество "Соликамский магниевый завод"',
#   'MGNZ',
#   'MGNZG',
#   'Соликамский магниевый завод',
#   'ОАО "СМЗ"',
#   'ОАО СМЗ',
#   '"Соликамский магниевый завод"'],
#  21: ['Публичное  акционерное общество "Русская Аквакультура"',
#   'AQUA',
#   'Инаркт1Р1',
#   'Инарктика',
#   'Русская Аквакультура',
#   'inarctica',
#   'Русское море',
#   '"Русская Аквакультура"'],
#  22: ['Публичное акционерное общество "Абрау – Дюрсо"',
#   'ABRD',
#   'Абрау – Дюрсо',
#   'abraudurso',
#   'Абрау Дюрсо',
#   '"Абрау – Дюрсо"'],
#  23: ['Публичное акционерное общество "Авиакомпания "ЮТэйр"',
#   'UTAR',
#   '"Авиакомпания "ЮТэйр"'],
#  24: ['Публичное акционерное общество "Акрон"',
#   'AKRN RX',
#   'акрон',
#   'Acron',
#   'AKRN',
#   '"Акрон"'],
#  25: ['Публичное акционерное общество "Акционерная нефтяная Компания "Башнефть"',
#   'BANE RX',
#   'Башнефть',
#   'BANE',
#   '"Акционерная нефтяная Компания "Башнефть"'],
#  26: ['Публичное акционерное общество "Акционерная финансовая корпорация "Система"',
#   'AFKS RX',
#   'АФК Система',
#   'Система',
#   'AFKS',
#   '"Акционерная финансовая корпорация "Система"'],
#  27: ['Публичное акционерное общество "АЛРОСА-Нюрба"',
#   'ALNU RX',
#   'Алроса',
#   'Alrosa',
#   'ALNU',
#   '"АЛРОСА-Нюрба"'],
#  28: ['Публичное акционерное общество "Аптечная сеть 36,6"',
#   'APTK RX',
#   'APTK',
#   '"Аптечная сеть 36,6"'],
#  29: ['Публичное акционерное общество "АСКО-СТРАХОВАНИЕ"',
#   'ACKO',
#   '"АСКО-СТРАХОВАНИЕ"'],
#  30: ['Публичное акционерное общество "Астраханская энергосбытовая компания"',
#   'ASSB',
#   'Астраханская ЭСБ',
#   '"Астраханская энергосбытовая компания"'],
#  31: ['Публичное акционерное общество "Ашинский металлургический завод"',
#   'AMEZ',
#   'AMEZ',
#   '"Ашинский металлургический завод"'],
#  32: ['Публичное акционерное общество "Аэрофлот – российские авиалинии"',
#   'AFLT RX',
#   'Аэрофлот',
#   'Aeroflot',
#   'AFLT',
#   '"Аэрофлот – российские авиалинии"'],
#  33: ['ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "БАНК "САНКТ-ПЕТЕРБУРГ"',
#   'BSPB RX',
#   'Банк Санкт-Петербург',
#   'БСПБ',
#   'Банк Петербург',
#   'СПБ Банк',
#   'BSPB',
#   '"БАНК "САНКТ-ПЕТЕРБУРГ"'],
#  34: ['Публичное акционерное общество "БАНК УРАЛСИБ"',
#   'USBN',
#   '"БАНК УРАЛСИБ"'],
#  35: ['Публичное акционерное общество "Башинформсвязь"',
#   'BISV',
#   '"Башинформсвязь"'],
#  36: ['Публичное акционерное общество "Белуга Групп"',
#   'BELU RX',
#   'Белуга',
#   'Beluga',
#   'BELU',
#   '"Белуга Групп"'],
#  37: ['Публичное акционерное общество "Бест Эффортс Банк"',
#   'ALBK',
#   '"Бест Эффортс Банк"'],
#  38: ['Публичное акционерное общество "Бурятзолото"', 'BRZL', '"Бурятзолото"'],
#  39: ['Публичное акционерное общество "Варьеганнефтегаз"',
#   'VJGZ',
#   '"Варьеганнефтегаз"'],
#  40: ['Публичное акционерное общество "Владимирский химический завод"',
#   'VLHZ',
#   'VLHZ',
#   '"Владимирский химический завод"'],
#  41: ['Публичное акционерное общество "Волгоградэнергосбыт"',
#   'VGSB',
#   'VGSB',
#   '"Волгоградэнергосбыт"'],
#  42: ['Публичное акционерное общество "Вторая генерирующая компания оптового рынка электроэнергии"',
#   'OGKB',
#   '"Вторая генерирующая компания оптового рынка электроэнергии"'],
#  43: ['Публичное акционерное общество "Выборгский судостроительный завод"',
#   'VSYD',
#   'VSYD',
#   '"Выборгский судостроительный завод"'],
#  44: ['Публичное акционерное общество "ГАЗ"',
#   'GAZA',
#   'группа "ГАЗ"',
#   'группа ГАЗ',
#   'ПАО Газ',
#   'ПАО "Газ"',
#   '"ГАЗ"'],
#  45: ['Публичное акционерное общество "ГАЗКОН"',
#   'GAZC',
#   'газкон',
#   'газкон-ао',
#   '"ГАЗКОН"'],
#  46: ['Публичное акционерное общество "Газпром газораспределение Ростов-на-Дону"',
#   'RTGZ',
#   'ПАО "Газпром газораспределение Ростов-на-Дону"',
#   'rostovoblgaz',
#   'Газпром РнД',
#   'Ростовоблгаз',
#   '"Газпром газораспределение Ростов-на-Дону"'],
#  47: ['Публичное акционерное общество "Газпром нефть"',
#   'SIBN RX',
#   'ПАО "Газпром нефть"',
#   'Газпром нефть',
#   'Gazprom Neft',
#   'SIBN',
#   '"Газпром нефть"'],
#  48: ['Публичное акционерное общество "Газпром"',
#   'GAZP RX',
#   'ПАО "Газпром"',
#   'Газпром',
#   'Gazprom',
#   'gazp',
#   'GAZP',
#   '"Газпром"'],
#  49: ['Публичное акционерное общество "ГАЗ-сервис"',
#   'GAZS',
#   'ПАО "ГАЗ-сервис"',
#   'gas-service',
#   '"ГАЗ-сервис"'],
#  50: ['Публичное акционерное общество "ГАЗ-Тек"',
#   'gazt',
#   'газ-тэк',
#   'gaz-tec',
#   '"ГАЗ-Тек"'],
#  51: ['Публичное акционерное общество "ГЕОТЕК Сейсморазведка"',
#   'GTSS',
#   'геотек',
#   'gseis',
#   'ПАО «ГЕОТЕК Сейсморазведка»',
#   '"ГЕОТЕК Сейсморазведка"'],
#  52: ['Публичное акционерное общество "ГЛОБАЛТРАК МЕНЕДЖМЕНТ"',
#   'GTRK',
#   'Глобалтрак',
#   'Globaltruck',
#   '"ГЛОБАЛТРАК МЕНЕДЖМЕНТ"'],
#  53: ['Публичное акционерное общество "Горно-металлургическая компания "Норильский никель"',
#   'GMKN RX',
#   'Норникель',
#   'ПАО "Горно-металлургическая компания "Норильский никель"',
#   'ПАО "ГМК "Норильский никель"',
#   'Nornickel',
#   'Норильский никель',
#   'GMKN',
#   '"Горно-металлургическая компания "Норильский никель"'],
#  54: ['Публичное акционерное общество "Городские Инновационные Технологии"',
#   'GRNT',
#   'ПАО «Городские Инновационные Технологии',
#   'ПАО "ГИТ"',
#   'Городские Инновационные Технологии',
#   'ГИТ',
#   '"Городские Инновационные Технологии"'],
#  55: ['Публичное акционерное общество "Группа Компаний  "Роллман"',
#   'RLMN',
#   'Роллман',
#   'Rollman',
#   '"Группа Компаний  "Роллман"'],
#  56: ['публичное акционерное общество "Группа компаний "Самолет"',
#   'SMLT RX',
#   'Самолет',
#   'Samolet',
#   'группа самолет',
#   'SMLT',
#   '"Группа компаний "Самолет"'],
#  57: ['Публичное акционерное общество "Группа ЛСР"',
#   'LSRG RX',
#   'ЛСР',
#   'LSRG',
#   '"Группа ЛСР"'],
#  58: ['Публичное акционерное общество "Группа Черкизово"',
#   'GCHE RX',
#   'Черкизово',
#   'Cherkizovo',
#   'GCHE',
#   '"Группа Черкизово"'],
#  59: ['Публичное акционерное общество "Дагестанская энергосбытовая компания"',
#   'DASB',
#   'ДагСб',
#   'Дагестанэнергосбыт',
#   'Dagestanskaya Energosbytovaya',
#   '"Дагестанская энергосбытовая компания"'],
#  60: ['Публичное акционерное общество "Дальневосточная энергетическая компания"',
#   'DVEC',
#   'ДЭК',
#   'Дальневосточная энергетическая компания',
#   '"Дальневосточная энергетическая компания"'],
#  61: ['Публичное акционерное общество "Дальневосточное морское пароходство"',
#   'FESH',
#   'ДВМП',
#   'FESCO',
#   'Дальневосточное морское пароходство',
#   '"Дальневосточное морское пароходство"'],
#  62: ['Публичное акционерное общество "Детский мир"',
#   'DSKY RX',
#   'Детский мир',
#   'Detsky Mir',
#   'Детмир',
#   'DSKY',
#   '"Детский мир"'],
#  63: ['Публичное акционерное общество "ДжиТиЭл"',
#   'GTLC',
#   'ДжиТиЭл',
#   'GTL',
#   '"ДжиТиЭл"'],
#  64: ['Публичное акционерное общество "Европейская Электротехника"',
#   'EELT',
#   'Европейская Электротехника',
#   'Yevropyeyskaya Elyektrotyekhnika',
#   '"Европейская Электротехника"'],
#  65: ['Публичное акционерное общество "Завод имени И.А. Лихачева"',
#   'ZILL',
#   'Завод имени И.А. Лихачева',
#   '"ЗИЛ"',
#   'ZIL',
#   'Завод имени Лихачёва',
#   "ЗИЛ'",
#   '"Завод имени И.А. Лихачева"'],
#  66: ['Публичное акционерное общество "ЗВЕЗДА"',
#   'ZVEZ',
#   'Звезда',
#   'ZVEZDA',
#   '"ЗВЕЗДА"'],
#  67: ['Публичное акционерное общество "Ижсталь"',
#   'IGST',
#   'Ижсталь',
#   'Ижевский металлургический завод',
#   "Izhstal'",
#   '"Ижсталь"'],
#  68: ['Публичное акционерное общество "ИНВЕСТ-ДЕВЕЛОПМЕНТ"',
#   'IDVP',
#   'инвест-девелопмент',
#   'invest-development',
#   '"ИНВЕСТ-ДЕВЕЛОПМЕНТ"'],
#  69: ['Публичное акционерное общество "ИНВЕСТИЦИОННАЯ КОМПАНИЯ ИК РУСС-ИНВЕСТ"',
#   'RUSI',
#   'Руссинвест',
#   'ИК Русс-Инвест',
#   'Russ-Invest',
#   'Русс-Инвест',
#   'Russinvest',
#   'Русс-Инвест ИК',
#   '"ИНВЕСТИЦИОННАЯ КОМПАНИЯ ИК РУСС-ИНВЕСТ"'],
#  70: ['Публичное акционерное общество "ИНГРАД"',
#   'INGR RX',
#   'OPIN',
#   'Инград',
#   'Ingrad',
#   'Ingr',
#   'Инград (ПАО)',
#   'ПАО Инград',
#   'INGR',
#   '"ИНГРАД"'],
#  71: ['Публичное акционерное общество "Институт Стволовых Клеток Человека"',
#   'ISKJ',
#   'ИСКЧ',
#   'Институт Стволовых Клеток Человека',
#   '"Институт Стволовых Клеток Человека"'],
#  72: ['Публичное акционерное общество "Интер РАО ЕЭС"',
#   'IRAO RX',
#   'Интер РАО',
#   'Inter Rao',
#   'Интер РАО ЕЭС Финанс',
#   'IRAO',
#   '"Интер РАО ЕЭС"'],
#  73: ['Публичное акционерное общество "Калужская сбытовая компания"',
#   'KLSB',
#   'КСК',
#   'КЛСБ',
#   'Калужская сбытовая компания',
#   'Калужская СбытКомп',
#   'Kalujskaya Sbytovaya',
#   '"Калужская сбытовая компания"'],
#  74: ['Публичное акционерное общество "КАМАЗ"',
#   'KMAZ RX',
#   'Камаз',
#   'Kamaz',
#   'KMAZ',
#   '"КАМАЗ"'],
#  75: ['Публичное акционерное общество "Каменск-Уральский завод по обработке цветных металлов"',
#   'KUNF',
#   'Кузоцм',
#   'Kuzocm',
#   '"Каменск-Уральский завод по обработке цветных металлов"'],
#  76: ['Публичное акционерное общество "Квадра - Генерирующая компания"',
#   'TGKD',
#   'АО Квадра',
#   'quadra',
#   'квадра',
#   'пао квадра',
#   '"Квадра - Генерирующая компания"'],
#  77: ['публичное акционерное общество "Ковровский механический завод"',
#   'KMEZ',
#   'ПАО КМЗ',
#   'Ковровский мехзд',
#   'Ковровский механический завод',
#   'kvmz',
#   '"Ковровский механический завод"'],
#  78: ['Публичное акционерное общество "Кокс"',
#   'KSGR',
#   'ПАО кокс',
#   'кокс',
#   'koks',
#   '"Кокс"'],
#  79: ['публичное акционерное общество "Корпорация ВСМПО-АВИСМА"',
#   'VSMO',
#   'Корпорация ВСМПО-АВИСМА',
#   'ВСМПО-АВИСМА',
#   'VSMPO-AVISMA Corporation',
#   'VSMPO-AVISMA',
#   'ВСМПО-АВСМ',
#   'ВСМПО',
#   '"Корпорация ВСМПО-АВИСМА"'],
#  80: ['Публичное акционерное общество "Коршуновский горно-обогатительный комбинат"',
#   'KOGK',
#   'Коршуновский гок',
#   'Korshunov Mining Plant',
#   'Korgok',
#   '"Коршуновский горно-обогатительный комбинат"'],
#  81: ['Публичное акционерное общество "Косогорский металлургический завод"',
#   'KMTZ',
#   'Косогорский металлургический завод',
#   'ПАО КМЗ',
#   'KGIW',
#   '"Косогорский металлургический завод"'],
#  82: ['Публичное акционерное общество "Костромская сбытовая компания"',
#   'KTSB',
#   'КСК',
#   'Костромская сбытовая компания',
#   'Kostromskaya sbytovaya kompaniya',
#   'KSK',
#   '"Костромская сбытовая компания"'],
#  83: ['Публичное акционерное общество "Краснокамский завод металлических сеток"',
#   'KZMS',
#   'КЗМС',
#   'Краснокамский завод металлических сеток',
#   'Россет',
#   'Rosset',
#   '"Краснокамский завод металлических сеток"'],
#  84: ['Публичное акционерное общество "Красноярскэнергосбыт"',
#   'KRSB',
#   'Красноярскэнергосбыт',
#   'krsk-sbit',
#   '"Красноярскэнергосбыт"'],
#  85: ['Публичное акционерное общество "Кузбасская Топливная Компания"',
#   'KBTK',
#   'Кузбасская топливная компания',
#   'КТК',
#   'KTK',
#   'ПАО КТК',
#   '"Кузбасская Топливная Компания"'],
#  86: ['Публичное акционерное общество "КуйбышевАзот"',
#   'KAZT',
#   'КуйбышевАзот',
#   'kuazot',
#   'Куйбазот',
#   '"КуйбышевАзот"'],
#  87: ['Публичное акционерное общество "Курганская генерирующая компания"',
#   'KGKC',
#   'Курганская генерирующая компания',
#   'Курганская ГК',
#   'КГК',
#   'ПАО КГК',
#   'KGK',
#   'Kurgancskaya Generiruyushaya',
#   '"Курганская генерирующая компания"'],
#  88: ['Публичное акционерное общество "М.видео"',
#   'MVID RX',
#   'Мвидео',
#   'Mvideo',
#   'MVID',
#   '"М.видео"'],
#  89: ['Публичное акционерное общество "Магнит"',
#   'MGNT RX',
#   'Магнит',
#   'Magnit',
#   'Mgnt',
#   'ПАО Магнит',
#   'Магнит ПАО',
#   'MGNT',
#   '"Магнит"'],
#  90: ['Публичное акционерное общество "Магнитогорский металлургический комбинат"',
#   'MAGN RX',
#   'ММК',
#   'Magnitigorskiy Metallurgicheskiy',
#   'Магнитогорский металлургический комбинат',
#   'Магнитка',
#   'MAGN',
#   '"Магнитогорский металлургический комбинат"'],
#  91: ['Публичное акционерное общество "МегаФон"',
#   'MFON RX',
#   'Мегафон',
#   'Megafon',
#   'ПАО Мегафон',
#   'Мегафон ПАО',
#   'MFON',
#   '"МегаФон"'],
#  92: ['Публичное акционерное общество "Медиахолдинг"',
#   'ODVA',
#   '"Медиахолдинг"'],
#  93: ['Публичное акционерное общество "Международный Медицинский Центр Обработки и Криохранения Биоматериалов"',
#   'GEMA',
#   '"Международный Медицинский Центр Обработки и Криохранения Биоматериалов"'],
#  94: ['Публичное акционерное общество "Межрегиональная распределительная сетевая компания Северо-Запада"',
#   'MRKZ',
#   '"Межрегиональная распределительная сетевая компания Северо-Запада"'],
#  95: ['Публичное акционерное общество "Межрегиональная распределительная сетевая компания Центра и Приволжья"',
#   'MRKP',
#   '"Межрегиональная распределительная сетевая компания Центра и Приволжья"'],
#  96: ['Публичное акционерное общество "Межрегиональная распределительная сетевая компания Центра"',
#   'MRKC',
#   '"Межрегиональная распределительная сетевая компания Центра"'],
#  97: ['Публичное акционерное общество "МЕРИДИАН"', 'MERF', '"МЕРИДИАН"'],
#  98: ['Публичное акционерное общество "МЕТКОМБАНК"', 'MTKB', '"МЕТКОМБАНК"'],
#  99: ['Публичное акционерное общество "Мечел"',
#   'MTLR RX',
#   'мечел',
#   'mechel',
#   'mtlrp',
#   'MTLR',
#   '"Мечел"'],
#  100: ['Публичное акционерное общество "Мобильные ТелеСистемы"',
#   'MTSS RX',
#   'MTC',
#   'МТС',
#   'MTSS',
#   '"Мобильные ТелеСистемы"'],
#  101: ['Публичное акционерное общество "Мордовская энергосбытовая компания"',
#   'MRSB',
#   '"Мордовская энергосбытовая компания"'],
#  102: ['Публичное акционерное общество "Морион"', 'MORI', '"Морион"'],
#  103: ['Публичное акционерное общество "Московская Биржа ММВБ-РТС"',
#   'MOEX RX',
#   'Мосбиржа',
#   'Московская биржа',
#   'MOEX',
#   '"Московская Биржа ММВБ-РТС"'],
#  104: ['Публичное акционерное общество "Московская городская телефонная сеть"',
#   'MGTS RX',
#   'MGTS',
#   '"Московская городская телефонная сеть"'],
#  105: ['Публичное акционерное общество "Московская кондитерская фабрика "Красный Октябрь"',
#   'KROT',
#   'KROTP',
#   '"Московская кондитерская фабрика "Красный Октябрь"'],
#  106: ['Публичное акционерное общество "МОСТОТРЕСТ"',
#   'mstt',
#   'мостотрест',
#   'mstt',
#   '"МОСТОТРЕСТ"'],
#  107: ['Публичное акционерное общество "Наука-Связь"',
#   'NSVZ',
#   'наука-связь',
#   '"Наука-Связь"'],
#  108: ['публичное акционерное общество "Научно-производственная корпорация "Иркут"',
#   'IRKT RX',
#   'IRKT',
#   '"Научно-производственная корпорация "Иркут"'],
#  109: ['Публичное акционерное общество "Научно-производственная корпорация "Объединенная Вагонная Компания"',
#   'UWGN RX',
#   'Объединенная Вагонная Компания',
#   'UWGN',
#   '"Научно-производственная корпорация "Объединенная Вагонная Компания"'],
#  110: ['Публичное акционерное общество "Нефтекамский автозавод"',
#   'NFAZ',
#   'нефаз',
#   'Нефтекамский автозавод',
#   '"Нефтекамский автозавод"'],
#  111: ['Публичное акционерное общество "Нефтяная компания "ЛУКОЙЛ"',
#   'LKOH RX',
#   'ЛУКОЙЛ',
#   'LKOH',
#   '"Нефтяная компания "ЛУКОЙЛ"'],
#  112: ['публичное акционерное общество "Нефтяная компания "Роснефть"',
#   'ROSN RX',
#   'роснефть',
#   'rosneft',
#   'ROSN',
#   '"Нефтяная компания "Роснефть"'],
#  113: ['Публичное Акционерное Общество "Нижнекамскнефтехим"',
#   'NKNCP',
#   'NKNC',
#   'Нижнекамскнефтехим',
#   'NKNCP',
#   '"Нижнекамскнефтехим"'],
#  114: ['Публичное акционерное общество "Нижнекамскшина"',
#   'NKSHP',
#   'NKSH',
#   'Нижнекамскшина',
#   'NKSHP',
#   '"Нижнекамскшина"'],
#  115: ['публичное акционерное общество "НОВАТЭК"',
#   'NVTK RX',
#   'Новатэк',
#   'Novatek',
#   'NVTK',
#   '"НОВАТЭК"'],
#  116: ['Публичное акционерное общество "Новолипецкий металлургический комбинат"',
#   'NLMK RX',
#   'НЛМК',
#   'NLMK',
#   '"Новолипецкий металлургический комбинат"'],
#  117: ['Публичное акционерное общество "Новороссийский комбинат хлебопродуктов"',
#   'NKHP',
#   'новороссийский комбинат хлебопродуктов',
#   'нкхп',
#   '"Новороссийский комбинат хлебопродуктов"'],
#  118: ['Публичное акционерное общество "Новороссийский морской торговый порт"',
#   'nmtp',
#   'нмтп',
#   'новороссийский морской порт',
#   'новороссийский морской торговый порт',
#   '"Новороссийский морской торговый порт"'],
#  119: ['Публичное акционерное общество "Новороссийское морское пароходство"',
#   'nompp',
#   'новошип',
#   'новороссийское морское пароходство',
#   '"Новороссийское морское пароходство"'],
#  120: ['Публичное акционерное общество "Объединенная авиастроительная корпорация"',
#   'UNAC RX',
#   'ПАО ОАК',
#   'ПАО "ОАК"',
#   'объединенная авиастроительная корпорация',
#   'UNAC',
#   '"Объединенная авиастроительная корпорация"'],
#  121: ['Публичное акционерное общество "Объединенные Кредитные Системы"',
#   'UCSS',
#   'Кредитные системы',
#   'Объединенные Кредитные Системы',
#   '"Объединенные Кредитные Системы"'],
#  122: ['Публичное акционерное общество "ОДК-Сатурн"',
#   'SATR',
#   'Сатурн',
#   'ОДК Сатурн',
#   'ОДК-Сатурн',
#   'ОДК_Сатурн',
#   '"ОДК-Сатурн"'],
#  123: ['Публичное акционерное общество "ОР"',
#   'ORUP',
#   'ОР ГРУПП',
#   'ПАО ОР',
#   '"ОР"'],
#  124: ['Публичное акционерное общество "Павловский автобус"',
#   'paza',
#   'Павловский автобус',
#   'Павл Автобус',
#   'ПавлБус',
#   '"Павловский автобус"'],
#  125: ['Публичное акционерное общество "Пермская энергосбытовая компания"',
#   'PMSBP',
#   'PMSB',
#   'ПЕРМЭНЕРГОСБЫТ',
#   'Пермская энергосбытовая компания',
#   'PMSBP',
#   '"Пермская энергосбытовая компания"'],
#  126: ['Публичное акционерное общество "ПИК-специализированный застройщик"',
#   'PIKK RX',
#   'ПИК СЗ',
#   'PIKK',
#   '"ПИК-специализированный застройщик"'],
#  127: ['Публичное акционерное общество "Полюс"',
#   'PLZL RX',
#   'Полюс',
#   'PLZL',
#   '"Полюс"'],
#  128: ['Публичное акционерное общество "Ракетно-космическая корпорация "Энергия" имени С.П. Королёва"',
#   'RKKE',
#   'Энергия',
#   'РКК Энергия',
#   'РКК «Энергия»',
#   '"Ракетно-космическая корпорация "Энергия" имени С.П. Королёва"'],
#  129: ['Публичное акционерное общество "Распадская"',
#   'RASP RX',
#   'ПАО «Распадская»',
#   'Распадская',
#   'RASP',
#   '"Распадская"'],
#  130: ['Публичное акционерное общество "РБК"',
#   'RBCM',
#   'РосБизнесКонсалтинг',
#   'ГК «РосБизнесКонсалтинг»',
#   'Рос Бизнес Консалтинг',
#   '"РБК"'],
#  131: ['Публичное акционерное общество "РН-Западная Сибирь"',
#   'CHGZ',
#   'РН-Западная Сибирь',
#   '"РН-Западная Сибирь"'],
#  132: ['Публичное акционерное общество "Росгосстрах Банк"',
#   'RGSC',
#   'Росгосстрах Банк',
#   'Банк Росгосстрах',
#   'РГС Банк',
#   'Росгосстрах',
#   '"Росгосстрах Банк"'],
#  133: ['Публичное акционерное общество "РОСИНТЕР РЕСТОРАНТС ХОЛДИНГ"',
#   'ROST',
#   'РОСИНТЕР РЕСТОРАНТС ХОЛДИНГ',
#   'РОСИНТЕР',
#   'Rosinter',
#   '"РОСИНТЕР РЕСТОРАНТС ХОЛДИНГ"'],
#  134: ['Публичное акционерное общество "Россети Волга"',
#   'mrkv',
#   'Россети Волга',
#   '"Россети Волга"'],
#  135: ['Публичное акционерное общество "Россети Кубань"',
#   'kube',
#   'Россети Кубань',
#   '"Россети Кубань"'],
#  136: ['Публичное акционерное общество "Россети Ленэнерго"',
#   'lsng',
#   'Россети Ленэнерго',
#   '"Россети Ленэнерго"'],
#  137: ['Публичное акционерное общество "Россети Московский регион"',
#   'MSRS',
#   'Россети Московский регион',
#   '"Россети Московский регион"'],
#  138: ['Публичное акционерное общество "Россети Северный Кавказ"',
#   'MRKK',
#   'Россети Северный Кавказ',
#   '"Россети Северный Кавказ"'],
#  139: ['Публичное акционерное общество "Россети Сибирь"',
#   'MRKS',
#   'Россети Сибирь',
#   '"Россети Сибирь"'],
#  140: ['Публичное акционерное общество "Россети Юг"', 'MRKY', '"Россети Юг"'],
#  141: ['Публичное акционерное общество "Российские сети"',
#   'RSTI RX',
#   'Российские сети',
#   'ПАО РОССЕТИ',
#   'РОССЕТИ',
#   'RSTI',
#   '"Российские сети"'],
#  142: ['Публичное акционерное общество "Ростелеком"',
#   'RTKM RX',
#   'ростелеком',
#   'RTKM',
#   '"Ростелеком"'],
#  143: ['Публичное акционерное общество "Русгрэйн Холдинг"',
#   'RUGR',
#   '"Русгрэйн Холдинг"'],
#  144: ['Публичное акционерное общество "Русолово"', 'ROLO', '"Русолово"'],
#  145: ['Публичное акционерное общество "Русполимет"', 'RUSP', '"Русполимет"'],
#  146: ['Публичное акционерное общество "Рязанская энергетическая сбытовая компания"',
#   'RZSB',
#   '"Рязанская энергетическая сбытовая компания"'],
#  147: ['Публичное акционерное общество "Саратовский нефтеперерабатывающий завод"',
#   'KRKN',
#   'KRKNP',
#   '"Саратовский нефтеперерабатывающий завод"'],
#  148: ['Публичное акционерное общество "Саратовэнерго"',
#   'SAREP',
#   'SARE',
#   'Саратовэнерго',
#   'SAREP',
#   '"Саратовэнерго"'],
#  149: ['Публичное акционерное общество "САФМАР Финансовые инвестиции"',
#   'SFIN RX',
#   'НПФ "Сафмар"',
#   'Сафмар',
#   'SFIN',
#   '"САФМАР Финансовые инвестиции"'],
#  150: ['Публичное акционерное общество "Сбербанк России"',
#   'SBER RX',
#   'Sberbank',
#   'Sber',
#   'сбербанк',
#   'сбер',
#   'SBER',
#   '"Сбербанк России"'],
#  151: ['Публичное акционерное общество "Светофор Групп"',
#   'SVET',
#   'Светофор Групп',
#   'Группа светофор',
#   '"Светофор Групп"'],
#  152: ['Публичное акционерное общество "Северсталь"',
#   'CHMF RX',
#   'северсталь',
#   'Северстал',
#   'CHMF',
#   '"Северсталь"'],
#  153: ['Публичное акционерное общество "Селигдар"',
#   'SELG',
#   'селигдар',
#   '"Селигдар"'],
#  154: ['Публичное Акционерное Общество "Сибирский гостинец"',
#   'SIBG',
#   '"Сибирский гостинец"'],
#  155: ['Публичное акционерное общество "Славнефть - Мегионнефтегаз"',
#   'MFGS',
#   '"Славнефть - Мегионнефтегаз"'],
#  156: ['Публичное акционерное общество "Славнефть-Ярославнефтеоргсинтез"',
#   'JNOS',
#   'JNOSP',
#   '"Славнефть-Ярославнефтеоргсинтез"'],
#  157: ['Публичное акционерное общество "Современный коммерческий флот"',
#   'FLOT RX',
#   'совкомфлот',
#   'FLOT',
#   '"Современный коммерческий флот"'],
#  158: ['Публичное акционерное общество "СОЛЛЕРС"',
#   'SVAV RX',
#   'соллерс',
#   'sollers',
#   'северсталь-авто',
#   'SVAV',
#   '"СОЛЛЕРС"'],
#  159: ['Публичное акционерное общество "Ставропольэнергосбыт"',
#   'STSB',
#   '"Ставропольэнергосбыт"'],
#  160: ['Публичное акционерное общество "Сургутнефтегаз"',
#   'SNGS RX',
#   'сургутнефтегаз',
#   'SNGS',
#   '"Сургутнефтегаз"'],
#  161: ['Публичное акционерное общество "Таганрогский котлостроительный завод "Красный котельщик"',
#   'KRKOP',
#   'ткз Красный котельщик',
#   'ткз "Красный котельщик"',
#   'Красный котельщик',
#   'PJSC Krasny Kotelshchik',
#   'Krasny Kotelshchik',
#   '"Таганрогский котлостроительный завод "Красный котельщик"'],
#  162: ['Публичное акционерное общество "Тамбовская энергосбытовая компания"',
#   'TASBP',
#   'Тамбовэнергосбыт',
#   'Тамбовская энергосбытовая компания',
#   'TASB',
#   '"Тамбовская энергосбытовая компания"'],
#  163: ['Публичное акционерное общество "Татнефть" имени В.Д. Шашина',
#   'TATN RX',
#   'Татнефть',
#   'Tatneft',
#   'TATN',
#   '"Татнефть"'],
#  164: ['Публичное акционерное общество "Таттелеком"',
#   'TTLK',
#   'Таттелеком',
#   'tattelecom',
#   '"Таттелеком"'],
#  165: ['Публичное акционерное общество "Территориальная генерирующая компания № 14"',
#   'TGKN',
#   'ТГК-14',
#   'TGC-14',
#   'TGK-14',
#   '"Территориальная генерирующая компания № 14"'],
#  166: ['Публичное акционерное общество "Территориальная генерирующая компания №1"',
#   'TGKA',
#   'ТГК-1',
#   'TGC-1',
#   'TGK-1',
#   '"Территориальная генерирующая компания №1"'],
#  167: ['Публичное акционерное общество "Территориальная генерирующая компания №2"',
#   'TGKB',
#   'ТГК-2',
#   'TGC-2',
#   'TGK-2',
#   '"Территориальная генерирующая компания №2"'],
#  168: ['Публичное акционерное общество "ТНС энерго Воронеж"',
#   'VRSB',
#   'ТНС энерго Воронеж',
#   'VRSBP',
#   '"ТНС энерго Воронеж"'],
#  169: ['Публичное акционерное общество "ТНС энерго Кубань"',
#   'KBSB',
#   'ТНС энерго Кубань',
#   'KBSBP',
#   'KBSBP',
#   '"ТНС энерго Кубань"'],
#  170: ['Публичное акционерное общество "ТНС энерго Марий Эл"',
#   'MISB',
#   'ТНС энерго Марий Эл',
#   'MISBP',
#   '"ТНС энерго Марий Эл"'],
#  171: ['Публичное акционерное общество "ТНС энерго Нижний Новгород"',
#   'NNSB',
#   'ТНС энерго Нижний Новгород',
#   'NNSB',
#   'ТНС энерго Нижний Новг',
#   'NNSBP',
#   '"ТНС энерго Нижний Новгород"'],
#  172: ['Публичное акционерное общество "ТНС энерго Ростов-на-Дону"',
#   'RTSB',
#   'ТНС энерго Ростов-на-Дону',
#   'RTSB',
#   'ТНС энерго Ростов',
#   'RTSBP',
#   '"ТНС энерго Ростов-на-Дону"'],
#  173: ['Публичное акционерное общество "ТНС энерго Ярославль"',
#   'YRSB',
#   'ТНС энерго Ярославль',
#   'YRSB',
#   'YRSBP',
#   '"ТНС энерго Ярославль"'],
#  174: ['Публичное акционерное общество "Томская распределительная компания"',
#   'TORS',
#   'Томская распределительная компания',
#   'Россети Томск',
#   'ТРК',
#   'TORS',
#   '"Томская распределительная компания"'],
#  175: ['Публичное акционерное общество "Транснефть"',
#   'TRNFP RX',
#   'Транснефть',
#   'transneft',
#   'TRNFP',
#   '"Транснефть"'],
#  176: ['Публичное акционерное общество "ТрансФин-М"',
#   'TRFM',
#   'ТрансФин',
#   'transfin',
#   'TRFM',
#   '"ТрансФин-М"'],
#  177: ['Публичное акционерное общество "Трубная Металлургическая Компания"',
#   'TRMK RX',
#   'ТМК',
#   'OAO TMK',
#   'TMK',
#   'Трубная Металлургическая Компания',
#   'TRMK',
#   '"Трубная Металлургическая Компания"'],
#  178: ['Публичное акционерное общество "Туймазинский завод автобетоновозов"',
#   'TUZA',
#   'ПАО «ТЗА»',
#   'ПАО ТЗА',
#   'тза',
#   'Туймазинский завод автобетоновозов',
#   'не TZA -- есть американский тикер',
#   'TUZA',
#   '"Туймазинский завод автобетоновозов"'],
#  179: ['Публичное акционерное общество "Тучковский комбинат строительных материалов"',
#   'TUCH',
#   'Тучковский КСМ',
#   'ТКСМ',
#   '"Тучковский комбинат строительных материалов"'],
#  180: ['Публичное акционерное общество "Угольная компания "Южный Кузбасс"',
#   'UKUZ',
#   'ПАО «Южный Кузбасс»',
#   'ПАО Южный Кузбасс',
#   'Southern Kuzbass Coal Company',
#   'Южный Кузбасс',
#   '"Угольная компания "Южный Кузбасс"'],
#  181: ['ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "УПРАВЛЯЮЩАЯ КОМПАНИЯ "АРСАГЕРА"',
#   'ARSA',
#   'ARSA',
#   'Арсагера',
#   'arsagera(не встречал упоминаний)',
#   '"УПРАВЛЯЮЩАЯ КОМПАНИЯ "АРСАГЕРА"'],
#  182: ['Публичное акционерное общество "Уралкалий"',
#   'URKA RX',
#   'uralkali',
#   'Уралкалий',
#   'URKA',
#   'URKA',
#   '"Уралкалий"'],
#  183: ['Публичное акционерное общество "Уральская кузница"',
#   'URKZ',
#   'Уральская кузница',
#   'Urals Stampings Plant',
#   '"Уральская кузница"'],
#  184: ['Публичное акционерное общество "Фармсинтез"',
#   'LIFE',
#   'Фармсинтез',
#   'Pharmsynthez',
#   'Фарм-синтез',
#   'ПАО Фармсинтез',
#   '"Фармсинтез"'],
#  185: ['Публичное акционерное общество "Федеральная гидрогенерирующая компания - РусГидро"',
#   'HYDR RX',
#   'Русгидро',
#   'RusHydro',
#   'ПАО РусГидро',
#   'HYDR',
#   '"Федеральная гидрогенерирующая компания - РусГидро"'],
#  186: ['Публичное акционерное общество "Федеральная сетевая компания Единой энергетической системы"',
#   'FEES RX',
#   'Россети ФСК ЕЭС',
#   'AO FGC UES',
#   'ПАО Россети',
#   'ПАО ФСК ЕЭС',
#   'ФСК ЕЭС',
#   'FEES',
#   '"Федеральная сетевая компания Единой энергетической системы"'],
#  187: ['Публичное акционерное общество "ФосАгро"',
#   'PHOR RX',
#   'Фосагро',
#   'Phosagro',
#   'PHOR',
#   '"ФосАгро"'],
#  188: ['Публичное акционерное общество "Химпром"',
#   'HIMCP RX',
#   'Химпром',
#   'himprom',
#   'ПАО Химпром',
#   'HIMCP',
#   '"Химпром"'],
#  189: ['Публичное акционерное общество "Центр международной торговли"',
#   'WTCM RX',
#   'ЦМТ',
#   'WTC',
#   'Центр международной торговли',
#   'World trade center',
#   'WTCM',
#   '"Центр международной торговли"'],
#  190: ['Публичное акционерное общество "Центр по перевозке грузов в контейнерах "ТрансКонтейнер"',
#   'TRCN RX',
#   'Трансконтейнер',
#   'Transcontainer',
#   'ПАО Трансконейнер',
#   'TRCN',
#   '"Центр по перевозке грузов в контейнерах "ТрансКонтейнер"'],
#  191: ['Публичное акционерное общество "Центральный телеграф"',
#   'CNTL RX',
#   'Центральный телеграф',
#   'Central Telegraph',
#   'ПАО Центральный телеграф',
#   'CNTL',
#   '"Центральный телеграф"'],
#  192: ['Публичное акционерное общество "Челябинский завод профилированного стального настила"',
#   'PRFN RX',
#   'ЧЗПСН-Профнастил',
#   'ПАО ЧЗПСН-Профнастил',
#   'Челябинский завод профилированного стального настила',
#   'PRFN',
#   '"Челябинский завод профилированного стального настила"'],
#  193: ['Публичное акционерное общество "Челябинский кузнечно-прессовый завод"',
#   'CKPZ RX',
#   'ЧКПЗ',
#   'OAO Chelyabinsk Forge-and-Press Plant',
#   'ПАО Челябинский кузнечно-прессовый завод',
#   'CKPZ',
#   '"Челябинский кузнечно-прессовый завод"'],
#  194: ['Публичное акционерное общество "Челябинский металлургический комбинат"',
#   'CHMK RX',
#   'ЧМК',
#   'Chelyabinsk Metallurgical Plant',
#   'ПАО ЧМК',
#   'Челябинский металлургический комбинат',
#   'ChMK',
#   'CHMK',
#   '"Челябинский металлургический комбинат"'],
#  195: ['Публичное акционерное общество "Челябинский трубопрокатный завод"',
#   'CHEP RX',
#   'ЧТПЗ',
#   'Chelyabinsk Pipe Rolling Plant',
#   'ПАО ЧТПЗ',
#   'Челябинский трубопрокатный завод',
#   'CHEP',
#   '"Челябинский трубопрокатный завод"'],
#  196: ['Публичное акционерное общество "Электроцинк"',
#   'ELTZ RX',
#   'Электроцинк',
#   'Electrozink',
#   'ПАО Электроцинк',
#   'ELTZ',
#   '"Электроцинк"'],
#  197: ['Публичное акционерное общество "Энел Россия"',
#   'ENRU RX',
#   'Энел Россия',
#   'Enel Russia',
#   'ПАО Энел Россия',
#   'elfv',
#   'Enel',
#   'ENRU',
#   '"Энел Россия"'],
#  198: ['Публичное акционерное общество "Южно-Уральский никелевый комбинат"',
#   'UNKL RX',
#   'Южуралникель',
#   'Unickel',
#   'Комбинат Южуралникель',
#   'ПАО Комбинат Южуралникель',
#   'UNKL',
#   '"Южно-Уральский никелевый комбинат"'],
#  199: ['Публичное акционерное общество "Юнипро"',
#   'UPRO RX',
#   'Юнипро',
#   'unipro',
#   'ПАО Юнипро',
#   'UPRO',
#   '"Юнипро"'],
#  200: ['Публичное акционерное общество "Якутская топливно-энергетическая компания"',
#   'YAKG RX',
#   'ЯТЭК',
#   'Yatec',
#   'Якутская топливно-энергетическая компания',
#   'ПАО Якутская топливно-энергетическая компания',
#   'YAKG',
#   '"Якутская топливно-энергетическая компания"'],
#  201: ['Публичное акционерное общество "Якутскэнерго"',
#   'YKEN RX',
#   'Якутскэнерго',
#   'Yakutskenergo',
#   'ПАО Якутскэнерго',
#   'YKEN',
#   '"Якутскэнерго"'],
#  202: ['Публичное акционерное общество Банк "Возрождение"',
#   'VZRZ RX',
#   'Банк Возрождение',
#   'Vozrozhdenie Bank',
#   'ПАО Банк Возрождение',
#   'VZRZ',
#   '"Возрождение"'],
#  203: ['Публичное акционерное общество Банк "Кузнецкий"',
#   'KUZB RX',
#   'Банк Кузнецкий',
#   'kuzbank',
#   'ПАО Банк Кузнецкий',
#   'KUZB',
#   '"Кузнецкий"'],
#  204: ['Публичное акционерное общество Группа компаний "Сегежа"',
#   'SGZH RX',
#   'сегежа',
#   'segezha',
#   'Сегежа групп',
#   'Segezha Group',
#   'SGZH',
#   '"Сегежа"'],
#  205: ['Публичное акционерное общество Группа компаний "ТНС энерго"',
#   'TNSE RX',
#   'ТНС энерго',
#   'TNS energo',
#   'ПАО ГК ТНС энерго',
#   'TNSE',
#   '"ТНС энерго"'],
#  206: ['Публичное акционерное общество Завод экологической техники и экопитания "ДИОД"',
#   'DIOD RX',
#   'Диод',
#   'DIOD Plant of Ecological Technics and Ecomeals',
#   'ПАО Диод',
#   'Завод экологической техники и экопитания Диод',
#   'DIOD',
#   '"ДИОД"'],
#  207: ['Публичное акционерное общество МОСКОВСКИЙ ОБЛАСТНОЙ БАНК', 'MOBB'],
#  208: ['Публичное акционерное общество Научно-производственное объединение "Наука"',
#   'NAUK',
#   '"Наука"'],
#  209: ['Публичное акционерное общество Нефтегазовая компания "РуссНефть"',
#   'RNFT',
#   '"РуссНефть"'],
#  210: ['Публичное акционерное общество Объединенные машиностроительные заводы (Группа Уралмаш-Ижора)',
#   'OMZZP',
#   'OMZZ',
#   'OMZZP'],
#  211: ['Публичное акционерное общество РОСБАНК', 'ROSB'],
#  212: ['Публичное акционерное общество Страховая Компания "Росгосстрах"',
#   'RGSS',
#   '"Росгосстрах"'],
#  213: ['Публичное акционерное общество энергетики и электрификации "Камчатскэнерго"',
#   'KCHEP',
#   'KCHE',
#   'KCHEP',
#   '"Камчатскэнерго"'],
#  214: ['Публичное акционерное общество энергетики и электрификации "Магаданэнерго"',
#   'MAGEP',
#   'MAGE',
#   'MAGEP',
#   '"Магаданэнерго"'],
#  215: ['Публичное акционерное общество энергетики и электрификации "Мосэнерго"',
#   'MSNG',
#   'мосэнерго',
#   'московская\xa0энергетическая компания',
#   '"Мосэнерго"'],
#  216: ['Публичное акционерное общество энергетики и электрификации "Самараэнерго"',
#   'SAGO',
#   'самарэнерго',
#   '"Самараэнерго"'],
#  217: ['Публичное акционерное общество энергетики и электрификации "Сахалинэнерго"',
#   'SLEN',
#   'сахалинэнерго',
#   '"Сахалинэнерго"'],
#  218: ['ETALON GROUP PLC (ЭТАЛОН ГРУП ПИЭЛСИ) (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))',
#   'ETLN LI',
#   'Эталон Груп',
#   'Группа Эталон',
#   'ETLN'],
#  219: ['Fix Price Group Ltd (Фикс Прайс Груп Лтд) (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))',
#   'FIXP RX',
#   'Fix Price',
#   'FixPrice',
#   'FIXP'],
#  220: ['Globaltrans Investment PLC (Глобалтранс Инвестмент ПЛС) (эмитент депозитарных расписок - Citibank N.A. (Ситибэнк Эн.Эй))',
#   'GLTR LI',
#   'Globaltrans',
#   'Глобалтранс',
#   'GLTR',
#   'GLTR'],
#  221: ['HeadHunter Group PLC (ХэдХантер Групп ПИЭЛСИ) (эмитент депозитарных расписок - JPMorgan Chase Bank, N.A. (ДжиПиМорган Чейз Банк, Эн.Эй))',
#   'HHRU RX',
#   'Headhunter',
#   'HHRU'],
#  222: ['HMS HYDRAULIC MACHINES & SYSTEMS GROUP PLC (ГМС ГИДРАВЛИК МАШИНС ЭНД СИСТЕМС ГРУП ПЛС) (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))',
#   'HMSG'],
#  223: ['Mail.ru Group Limited (Мэйл.ру Груп Лимитед) (эмитент депозитарных расписок - Citibank N.A. (Ситибэнк Эн.Эй))',
#   'MAIL LI',
#   'VKCO',
#   'Вконтакте',
#   '"ВК"',
#   'VK Group',
#   "ВК'",
#   'MAIL'],
#  224: ['MD MEDICAL GROUP INVESTMENTS PLC (МД МЕДИКАЛ ГРУП ИНВЕСТМЕНТС ПЛС) (эмитент депозитарных расписок - JPMorgan Chase Bank, N.A. (ДжиПиМорган Чейз Банк, Эн.Эй))',
#   'MDMG RX',
#   'MD Medical',
#   'MDMG'],
#  225: ['TCS Group Holding PLC (ТиСиЭс Груп Холдинг ПиЭлСи) (эмитент депозитарных расписок - JPMorgan Chase Bank, N.A. (ДжиПиМорган Чейз Банк, Эн.Эй))',
#   'TCS LI',
#   'TCSG',
#   'TCS Group',
#   'Tinkoff',
#   'Тинькофф',
#   'TCS'],
#  226: ["АО О'КЕЙ ГРУПП (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))",
#   'OKEY RX',
#   'OKEY'],
#  227: ['Икс 5 Ритейл Груп Н.В. (X5 Retail Group N.V.) (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))',
#   'FIVE LI',
#   'Х5 групп',
#   'X5 Group',
#   'FIVE'],
#  228: ['КИВИ ПиЭлСи (QIWI PLC) (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))',
#   'QIWI RX',
#   'АО Киви',
#   'QIWI'],
#  229: ['Международная компания публичное акционерное общество "Лента" (эмитент депозитарных расписок - Deutsche Bank Trust Company Americas (Дойче Банк Траст Кампани Америкас))',
#   'LNTA',
#   'LENT',
#   '"Лента"'],
#  230: ['Озон Холдингс ПиЭлСи (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))',
#   'OZON RX',
#   'OZON'],
#  231: ['РОС АГРО ПЛС (ROS AGRO PLC) (эмитент депозитарных расписок - The Bank of New York Mellon (Бэнк оф Нью Йорк Меллон))',
#   'AGRO RX',
#   'Русагро',
#   'Rusagro',
#   'AGRO'],
#  232: ['Nord Gold PLC (Норд Голд ПЛК)', 'RTSD'],
#  233: ['UNITED MEDICAL GROUP CY PLC (ЮНАЙТЕД МЕДИКАЛ ГРУП КИ ПИЭЛСИ) (эмитент депозитарных расписок - The Bank of New York Mellon Corporation (Зе Бэнк оф Нью Йорк Меллон Корпорэйшн))',
#   'NORD',
#   'Nordgold'],
#  234: ['Petropavlovsk PLC (Петропавловск ПЛК)',
#   'POGR',
#   'Petropavl',
#   '"Петропавловск"'],
#  235: ['Полиметалл Интернэшнл плс (Polymetal International plc)',
#   'POLY RX',
#   'polymetal',
#   'полиметалл',
#   'POLY'],
#  236: ['Публичная Компания с ограниченной ответственностью Яндекс Н.В. (Public Limited Liability Company Yandex N.V.)',
#   'YNDX RX',
#   'Яндекс',
#   'Yandex',
#   'YNDX'],
#  237: ['Softline Holding Limited (эмитент депозитарных расписок - The Bank of New York Mellon Corporation (Зе Бэнк оф Нью Йорк Меллон Корпорэйшн))',
#   'SFTL',
#   'softline',
#   'софтлайн',
#   'Noventiq'],
#  240: ['VEON Ltd.', 'VEON', 'ВЕОН'],
#  241: ['Публичное акционерное общество "Группа Позитив"',
#   'POSI',
#   'Positive tech',
#   'группа позитив',
#   'гр. Позитив',
#   'Positive Group',
#   '"Группа Позитив"'],
#  251: ['Cian PLC (эмитент депозитарных расписок - The Bank of New York Mellon)',
#   'CIAN',
#   'cian',
#   'циан'],
#  254: ['Публичное акционерное общество "ВУШ Холдинг"',
#   'WUSH',
#   'Whoosh',
#   'Вуш',
#   '"ВУШ Холдинг"'],
#  255: ['Публичное акционерное общество "СПБ Биржа"',
#   'SPBE',
#   'СПБ Биржа',
#   '"СПБ Биржа"'],
#  257: ['Global Ports', 'GLPR', 'Globalports', 'Глобалпортс'],
#  267: ['Публичное акционерное общество "Группа Ренессанс Страхование"',
#   'RENI',
#   'Ренессанс Страхование',
#   '"Группа Ренессанс Страхование"'],
#  258: ['Astra Linux', 'ASTR', 'Гк Астра', 'Группа Астра', 'Astra', 'Астра'],
#  261: ['INARCTICA',
#   'AQUA',
#   'Инарктика',
#   'Русское море',
#   'Русская аквакультура',
#   'Аквакультура'],
#  265: ['ЮЖУРАЛЗОЛОТО', 'UGLD', 'ЮГК'],
#  266: ['Artgen biotech', 'ABIO', 'Артген Биотех', 'Артген', 'iАРТГЕН'],
#  268: ['Генетико', 'GECO', 'Genetico', 'iГенетико'],
#  269: ['CarMoney', 'CARM', 'Смарттехгрупп', 'ПАО "СТГ"'],
#  270: ['Henderson', 'HNFG', 'Хендерсон'],
#  271: ['Совкомбанк', 'SVCB', 'Sovcombank'],
#  272: ['ЕвроТранс', 'EUTR', 'АЗС Трасса', 'АЗС "Трасса"', 'АЗС «Трасса»'],
#  273: ['Делимобиль',
#   'DELI',
#   'Делимобил',
#   'Каршеринг Рус',
#   'delimobil',
#   'ПАО "Каршеринг Руссия"',
#   '"Каршеринг Руссия", ПАО'],
#  274: ['Диасофт', 'DIAS', 'Diasoft']}

# %% [markdown]
# Обучим префиксное дерево распознавать организации:

# %%
keyword_preprocessor = KeywordProcessor()
keyword_preprocessor.add_keywords_from_dict(keyword_dict)

# %%
samples['keywords'] = samples['MessageText'].progress_apply(keyword_preprocessor.extract_keywords).apply(lambda x: list(set(x)))

# %%
samples[['issuerid', 'keywords']]
# Out:
#        issuerid                                           keywords
# 3725        187                                                 []
# 13914       150                                              [150]
# 9347        175                                              [175]
# 7527          7                                           [142, 7]
# 4336          7                                                [7]
# ...         ...                                                ...
# 6733        220                  [100, 230, 7, 231, 235, 175, 220]
# 1297        225  [225, 227, 99, 230, 236, 141, 142, 47, 112, 11...
# 9422         25     [89, 163, 111, 112, 48, 115, 150, 25, 27, 127]
# 18342        44                                               [44]
# 3070        153                               [153, 235, 265, 127]
#
# [1100 rows x 2 columns]

# %%
samples['predict'] = samples.apply(lambda x: x['issuerid'] if x['issuerid'] in x['keywords'] else 4242, axis=1)

# %%
samples[samples['predict'] == 4242].shape
# Out:
# (63, 12)

# %% [markdown]
# Среднее время выполнения:

# %%
# %%timeit

samples['keywords'] = samples['MessageText'].apply(keyword_preprocessor.extract_keywords).apply(lambda x: list(set(x)))
# Out:
# 1.2 s ± 125 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# F1 score считаем следующим образом: если нашли упоминание компании issuerid, то 1, иначе 0

# %%
f1_score(samples['issuerid'], samples['predict'], average='macro')
# Out:
# 0.9219246355250649

# %% [markdown]
# Проверим на всем датасете:

# %%
df['keywords'] = df['MessageText'].progress_apply(keyword_preprocessor.extract_keywords).apply(lambda x: list(set(x)))
df['predict'] = df.apply(lambda x: x['issuerid'] if x['issuerid'] in x['keywords'] else 4242, axis=1)

f1_score(df['issuerid'], df['predict'], average='macro')
# Out:
# 100%|██████████| 19355/19355 [00:30<00:00, 644.63it/s]
# 0.9441922260844381

# %%
30 / 19335 * 1000
# Out:
# 1.5515903801396431
